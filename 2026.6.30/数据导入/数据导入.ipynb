# %%
import numpy as np
import pandas as pd

df = pd.read_csv('用户数据.csv')
df
# Out:
#     姓名  年龄 性别                     邮箱           电话  城市     职业
# 0   张伟  28  男   zhangwei@example.com  13800138001  北京  软件工程师
# 1   李娜  32  女       lina@example.com  13800138002  上海   产品经理
# 2   王强  25  男  wangqiang@example.com  13800138003  广州  数据分析师
# 3   刘芳  29  女    liufang@example.com  13800138004  深圳  UI设计师
# 4   陈杰  35  男    chenjie@example.com  13800138005  杭州    架构师
# 5   赵敏  27  女    zhaomin@example.com  13800138006  成都   运营经理
# 6   孙磊  31  男     sunlei@example.com  13800138007  武汉   后端开发
# 7   周婷  26  女   zhouting@example.com  13800138008  南京   市场专员
# 8   吴昊  40  男      wuhao@example.com  13800138009  重庆   技术总监
# 9   郑静  33  女  zhengjing@example.com  13800138010  西安   人力资源
# 10  钱进  22  男    qianjin@example.com  13800138011  苏州   前端开发
# 11  马丽  30  女       mali@example.com  13800138012  长沙   财务经理
# 12  黄波  38  男    huangbo@example.com  13800138013  郑州   项目经理
# 13  许慧  24  女      xuhui@example.com  13800138014  东莞  测试工程师
# ...

# %%
print(df.年龄.mean())
# Out:
# 30.2

# %%
df = df.tail()
df.to_csv('new.csv')

# %%
df = pd.read_json('user_date.json')
print(type(df))
df
# Out:
# <class 'pandas.DataFrame'>
#     姓名  年龄 性别                     邮箱           电话  城市     职业
# 0   张伟  28  男   zhangwei@example.com  13800138001  北京  软件工程师
# 1   李娜  32  女       lina@example.com  13800138002  上海   产品经理
# 2   王强  25  男  wangqiang@example.com  13800138003  广州  数据分析师
# 3   刘芳  29  女    liufang@example.com  13800138004  深圳  UI设计师
# 4   陈杰  35  男    chenjie@example.com  13800138005  杭州    架构师
# 5   赵敏  27  女    zhaomin@example.com  13800138006  成都   运营经理
# 6   孙磊  31  男     sunlei@example.com  13800138007  武汉   后端开发
# 7   周婷  26  女   zhouting@example.com  13800138008  南京   市场专员
# 8   吴昊  40  男      wuhao@example.com  13800138009  重庆   技术总监
# 9   郑静  33  女  zhengjing@example.com  13800138010  西安   人力资源
# 10  钱进  22  男    qianjin@example.com  13800138011  苏州   前端开发
# 11  马丽  30  女       mali@example.com  13800138012  长沙   财务经理
# 12  黄波  38  男    huangbo@example.com  13800138013  郑州   项目经理
# 13  许慧  24  女      xuhui@example.com  13800138014  东莞  测试工程师
# ...

# %%
import json
with open('user_date.json') as f:
    data = json.load(f)
print(data)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[18], line 3
#       1 import json
#       2 with open('user_date.json') as f:
# ----> 3     data = json.load(f)
#       4 print(data)
#
# File C:\Program Files\Python311\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)    291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
# ...
