# %% [markdown]
# **onnx格式的学习**

# %% [markdown]
# **定义**：ONNX可以比作一种专门的编程语言 在数学函数中。它定义了所有必要的操作 机器学习模型需要实现其推理函数 用这种语言。ONNX旨在提供一种通用的机器学习框架 可以用来描述其模型。ONNX 使用 protobuf 将图序列化为 一个单一块 （参见解析与序列化）其目标是优化模型尺寸。

# %% [markdown]
# **子图**：属性是算符的固定参数。Operator Gemm有四个属性：α、β、transA、transB。 除非运行时间 允许通过其 API 加载 ONNX 图，这些值 无法更改，所有预测都无法冻结。

# %% [markdown]
# 它会转化成CPU可读指令
# **性质**：AI推理引擎
