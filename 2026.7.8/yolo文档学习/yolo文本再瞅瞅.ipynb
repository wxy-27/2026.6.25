# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
model = YOLO("yolo26n.yaml")

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo26n.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="coco8.yaml", epochs=3)

# Evaluate the model's performance on the validation set
results = model.val()

# Perform object detection on an image using the model
results = model("bus.jpg")

# Export the model to ONNX format
success = model.export(format="onnx")
# Out:
# Ultralytics 8.4.90  Python-3.11.4 torch-2.12.1+cpu CPU (13th Gen Intel Core i7-1360P)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=3, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\runs\detect\train-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    309656  ultralytics.nn.modules.head.Detect           [80, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,572,280 parameters, 2,572,280 gradients, 6.1 GFLOPs
#
# Transferred 708/708 items from pretrained weights
# WARNING train: Slow image access detected (ping: 0.60.0 ms, read: 42.015.3 MB/s, size: 50.0 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning C:\datasets\coco8\labels\train.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4  0.0s
# val: Fast image access  (ping: 0.40.1 ms, read: 63.740.3 MB/s, size: 54.0 KB)
# val: Scanning C:\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to C:\runs\detect\train-2\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\runs\detect\train-2
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3         0G      1.334      2.658     0.0142         24        640: 100% ━━━━━━━━━━━━ 1/1 3.0s/it 3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                    all          4         17      0.907       0.65      0.902      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3         0G      1.479      2.472    0.01784         28        640: 100% ━━━━━━━━━━━━ 1/1 2.8s/it 2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                    all          4         17      0.893      0.656      0.902      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3         0G      1.265      2.346    0.01911         19        640: 100% ━━━━━━━━━━━━ 1/1 3.0s/it 3.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.2s/it 1.2s
#                    all          4         17      0.878      0.663      0.904      0.665
#
# 3 epochs completed in 0.004 hours.
# Optimizer stripped from C:\runs\detect\train-2\weights\last.pt, 5.5MB
# Optimizer stripped from C:\runs\detect\train-2\weights\best.pt, 5.5MB
#
# Validating C:\runs\detect\train-2\weights\best.pt...
# Ultralytics 8.4.90  Python-3.11.4 torch-2.12.1+cpu CPU (13th Gen Intel Core i7-1360P)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all          4         17      0.892      0.656      0.902      0.666
#                 person          3         10          1      0.434      0.772      0.386
#                    dog          1          1      0.747          1      0.995      0.597
#                  horse          1          2      0.822          1      0.995      0.795
#               elephant          1          2      0.781        0.5      0.662      0.427
#               umbrella          1          1          1          1      0.995      0.895
#           potted plant          1          1          1          0      0.995      0.895
# Speed: 1.9ms preprocess, 170.8ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to C:\runs\detect\train-2
# Ultralytics 8.4.90  Python-3.11.4 torch-2.12.1+cpu CPU (13th Gen Intel Core i7-1360P)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
# val: Fast image access  (ping: 0.50.1 ms, read: 88.853.4 MB/s, size: 54.0 KB)
# val: Scanning C:\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.7it/s 0.6s
#                    all          4         17      0.892      0.656      0.902      0.666
#                 person          3         10          1      0.434      0.772      0.386
#                    dog          1          1      0.747          1      0.995      0.597
#                  horse          1          2      0.822          1      0.995      0.795
#               elephant          1          2      0.781        0.5      0.662      0.427
#               umbrella          1          1          1          1      0.995      0.895
#           potted plant          1          1          1          0      0.995      0.895
# Speed: 2.2ms preprocess, 135.0ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to C:\runs\detect\val-2
#
# image 1/1 C:\Users\wangx\Desktop\bus.jpg: 640x480 4 persons, 1 bus, 247.3ms
# Speed: 9.8ms preprocess, 247.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
# Ultralytics 8.4.90  Python-3.11.4 torch-2.12.1+cpu CPU (13th Gen Intel Core i7-1360P)
#
# PyTorch: starting from 'C:\runs\detect\train-2\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (5.3 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxruntime', 'onnxslim>=0.1.82'] not found, attempting AutoUpdate...
# WARNING Retry 1/2 failed: 'gbk' codec can't decode byte 0x82 in position 907: illegal multibyte sequence
# WARNING Retry 2/2 failed: 'gbk' codec can't decode byte 0x82 in position 907: illegal multibyte sequence
# WARNING requirements:  'gbk' codec can't decode byte 0x82 in position 907: illegal multibyte sequence
# ERROR ONNX: export failure 93.3s: No module named 'onnx'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 19
#      15 # Perform object detection on an image using the model
#      16 results = model("bus.jpg")
#      17
#      18 # Export the model to ONNX format
# ---> 19 success = model.export(format="onnx")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\model.py:720, in Model.export(self, **kwargs)
#     712 custom = {
#     713     "imgsz": self.model.args["imgsz"],
#     714     "batch": 1,
#    (...)    717     "verbose": False,
#     718 }  # method defaults
#     719 args = {**self.overrides, **custom, **kwargs, "mode": "export"}  # highest priority args on the right
# --> 720 return Exporter(overrides=args, _callbacks=self.callbacks)(model=self.model)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\exporter.py:811, in Exporter.__call__(self, model)
#     809         f = self.export_edgetpu(tflite_model=Path(f) / f"{self.file.stem}_full_integer_quant.tflite")
#     810 else:
# --> 811     f = getattr(self, f"export_{fmt}")()
#     813 # Finish
#     814 if f:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\exporter.py:433, in try_export.<locals>.outer_func(*args, **kwargs)
#     431 except Exception as e:
#     432     LOGGER.error(f"{prefix} export failure {dt.t:.1f}s: {e}")
# --> 433     raise e
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\exporter.py:425, in try_export.<locals>.outer_func(*args, **kwargs)
#     423 try:
#     424     with Profile() as dt:
# --> 425         f = inner_func(*args, **kwargs)  # exported file/dir or tuple of (file/dir, *)
#     426     path = f if isinstance(f, (str, Path)) else f[0]
#     427     mb = file_size(path)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\exporter.py:898, in Exporter.export_onnx(self, prefix)
#     896     requirements += ["onnxslim>=0.1.82"]
#     897 check_requirements(requirements)
# --> 898 import onnx
#     900 from ultralytics.utils.export.engine import best_onnx_opset, torch2onnx
#     902 opset = self.args.opset or best_onnx_opset(onnx, cuda="cuda" in self.device.type)
#
# ModuleNotFoundError: No module named 'onnx'

# %%
from ultralytics import settings

# View all settings
print(settings)

# Return a specific setting
value = settings["runs_dir"]
# Out:
# JSONDict("C:\Users\wangx\AppData\Roaming\Ultralytics\settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "C:\\datasets",
#   "weights_dir": "C:\\weights",
#   "runs_dir": "C:\\runs",
#   "uuid": "20397a4a61ec54dfab464ac67221b6efede16aaa15d47cb201c3a52451064cbf",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": false,
#   "wandb": false,
#   "vscode_msg": true,
#   "openvino_msg": false
# }

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo26n.pt")  # pretrained YOLO26n model

# Run batched inference on a list of images
results = model(["2.jpg", "bus.jpg"])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
# Out:
# 0: 640x640 9 cakes, 153.3ms
# 1: 640x640 4 persons, 1 bus, 153.3ms
# Speed: 5.5ms preprocess, 153.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo26n.pt")  # pretrained YOLO26n model

# Run batched inference on a list of images
results = model(["2.jpg", "bus.jpg"], stream=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
# Out:
# 0: 640x640 9 cakes, 184.6ms
# 1: 640x640 4 persons, 1 bus, 184.6ms
# Speed: 7.9ms preprocess, 184.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO

# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

# Define path to the image file
source = "bus.jpg"

# Run inference on the source
results = model(source)  # list of Results objects
# Out:
# image 1/1 C:\Users\wangx\Desktop\bus.jpg: 640x480 4 persons, 1 bus, 165.5ms
# Speed: 5.1ms preprocess, 165.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)

# %%
import cv2

from ultralytics import YOLO

# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

# Read an image using OpenCV
source = cv2.imread("2.jpg")

# Run inference on the source
results = model(source)  # list of Results objects
# Out:
# 0: 640x640 9 cakes, 126.3ms
# Speed: 7.1ms preprocess, 126.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO

# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

# Define a path to a CSV file with images, URLs, videos and directories
source = "bus.jpg"

# Run inference on the source
results = model(source)  # list of Results objects
# Out:
# image 1/1 C:\Users\wangx\Desktop\bus.jpg: 640x480 4 persons, 1 bus, 143.4ms
# Speed: 5.0ms preprocess, 143.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)

# %%
from ultralytics import YOLO

# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

# Define path to video file
source = "baby.mp4"

# Run inference on the source
results = model(source, stream=True)  # generator of Results objects

# %%
from ultralytics import YOLO

# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

# Run inference on 'bus.jpg' with arguments
model.predict("bus.jpg", save=True, imgsz=320, conf=0.25)
# Out:
# image 1/1 C:\Users\wangx\Desktop\bus.jpg: 320x256 5 persons, 1 bus, 73.1ms
# Speed: 1.7ms preprocess, 73.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 256)
# Results saved to C:\runs\detect\predict-3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[119, 146, 172],
#          [121, 148, 174],
#          [122, 152, 177],
#          ...,
#          [161, 171, 188],
#          [160, 170, 187],
#          [160, 170, 187]],
#
#         [[120, 147, 173],
#          [122, 149, 175],
#          [123, 153, 178],
#          ...,
#          [161, 171, 188],
#          [160, 170, 187],
#          [160, 170, 187]],
#
#         [[123, 150, 176],
#          [124, 151, 177],
#          [125, 155, 180],
#          ...,
#          [161, 171, 188],
#          [160, 170, 187],
#          [160, 170, 187]],
#
#         ...,
#
#         [[183, 182, 186],
#          [179, 178, 182],
#          [180, 179, 183],
#          ...,
#          [121, 111, 117],
#          [113, 103, 109],
#          [115, 105, 111]],
#
#         [[165, 164, 168],
#          [173, 172, 176],
#          [187, 186, 190],
#          ...,
#          [102,  92,  98],
#          [101,  91,  97],
#          [103,  93,  99]],
#
#         [[123, 122, 126],
#          [145, 144, 148],
#          [176, 175, 179],
#          ...,
#          [ 95,  85,  91],
#          [ 96,  86,  92],
#          [ 98,  88,  94]]], shape=(1080, 810, 3), dtype=uint8)
#  orig_shape: (1080, 810)
#  path: 'C:\\Users\\wangx\\Desktop\\bus.jpg'
#  probs: None
#  save_dir: 'C:\\runs\\detect\\predict-3'
#  semantic_mask: None
#  speed: {'preprocess': 1.703399932011962, 'inference': 73.08659993577749, 'postprocess': 0.6033000536262989}]

# %%
from ultralytics import YOLO

# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

# Run inference on 'bus.jpg' with arguments
model.predict("2.jpg", save=True, imgsz=320, conf=0.25)
# Out:
# image 1/1 C:\Users\wangx\Desktop\2.jpg: 320x320 6 cakes, 97.2ms
# Speed: 1.6ms preprocess, 97.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to C:\runs\detect\predict-4
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[197, 183, 185],
#          [197, 183, 185],
#          [197, 183, 185],
#          ...,
#          [197, 184, 184],
#          [196, 182, 184],
#          [196, 182, 184]],
#
#         [[197, 183, 185],
#          [197, 183, 185],
#          [197, 183, 185],
#          ...,
#          [197, 184, 184],
#          [196, 182, 184],
#          [196, 182, 184]],
#
#         [[197, 183, 185],
#          [197, 183, 185],
#          [197, 183, 185],
#          ...,
#          [197, 184, 184],
#          [196, 182, 184],
#          [196, 182, 184]],
#
#         ...,
#
#         [[196, 184, 186],
#          [196, 184, 186],
#          [196, 184, 186],
#          ...,
#          [196, 184, 186],
#          [198, 184, 186],
#          [198, 184, 186]],
#
#         [[196, 184, 186],
#          [196, 184, 186],
#          [196, 184, 186],
#          ...,
#          [198, 184, 186],
#          [200, 185, 187],
#          [200, 185, 187]],
#
#         [[196, 184, 186],
#          [196, 184, 186],
#          [196, 184, 186],
#          ...,
#          [198, 184, 186],
#          [200, 185, 187],
#          [200, 185, 187]]], shape=(658, 658, 3), dtype=uint8)
#  orig_shape: (658, 658)
#  path: 'C:\\Users\\wangx\\Desktop\\2.jpg'
#  probs: None
#  save_dir: 'C:\\runs\\detect\\predict-4'
#  semantic_mask: None
#  speed: {'preprocess': 1.5842999564483762, 'inference': 97.21409995108843, 'postprocess': 0.5796999903395772}]

# %%
from ultralytics import YOLO

# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

# Run inference on an image
results = model("bus.jpg")
results = model(
    [
        "bus.jpg",
        "2.jpg",
    ]
)  # batch inference
# Out:
# image 1/1 C:\Users\wangx\Desktop\bus.jpg: 640x480 4 persons, 1 bus, 118.9ms
# Speed: 3.0ms preprocess, 118.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x640 4 persons, 1 bus, 130.2ms
# 1: 640x640 9 cakes, 130.2ms
# Speed: 6.5ms preprocess, 130.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# 单GPU设置下训练它

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo26n.yaml")  # build a new model from YAML
model = YOLO("yolo26n.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo26n.yaml").load("yolo26n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="coco8.yaml", epochs=100, imgsz=640)
# Out:
# Transferred 708/708 items from pretrained weights
# Ultralytics 8.4.90  Python-3.11.4 torch-2.12.1+cpu CPU (13th Gen Intel Core i7-1360P)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=yolo26n.pt, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\runs\detect\train-4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    309656  ultralytics.nn.modules.head.Detect           [80, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,572,280 parameters, 2,572,280 gradients, 6.1 GFLOPs
#
# Transferred 708/708 items from pretrained weights
# train: Fast image access  (ping: 0.40.0 ms, read: 89.537.4 MB/s, size: 50.0 KB)
# train: Scanning C:\datasets\coco8\labels\train.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4  0.0s
# val: Fast image access  (ping: 0.40.0 ms, read: 93.744.6 MB/s, size: 54.0 KB)
# val: Scanning C:\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to C:\runs\detect\train-4\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\runs\detect\train-4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      1.334      2.658     0.0142         24        640: 100% ━━━━━━━━━━━━ 1/1 2.8s/it 2.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 0% ──────────── 0/1  0.9s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 9
#       5 model = YOLO("yolo26n.pt")  # load a pretrained model (recommended for training)
#       6 model = YOLO("yolo26n.yaml").load("yolo26n.pt")  # build from YAML and transfer weights
#       7
#       8 # Train the model
# ----> 9 results = model.train(data="coco8.yaml", epochs=100, imgsz=640)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\model.py:814, in Model.train(self, trainer, **kwargs)
#     811     self.trainer.model = self.trainer.get_model(weights=weights, cfg=self.model.yaml)
#     812     self.model = self.trainer.model
# --> 814 self.trainer.train()
#     815 # Update model and cfg after training
#     816 if RANK in {-1, 0}:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\trainer.py:241, in BaseTrainer.train(self)
#     238             ddp_cleanup(self, str(file))
#     240 else:
# --> 241     self._do_train()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\trainer.py:549, in BaseTrainer._do_train(self)
#     547 if self.args.val or final_epoch or self.stopper.possible_stop or self.stop:
#     548     self._clear_memory(None if self.device.type == "mps" else 0.5)  # prevent VRAM spike
# --> 549     self.metrics, self.fitness = self.validate()
#     551 # NaN recovery
#     552 if self._handle_nan_recovery(epoch):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\trainer.py:811, in BaseTrainer.validate(self)
#     809     for buffer in self.ema.ema.buffers():
#     810         dist.broadcast(buffer, src=0)
# --> 811 metrics = self.validator(self)
#     812 if metrics is None:
#     813     return None, None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\validator.py:248, in BaseValidator.__call__(self, trainer, model)
#     246     with dt[2]:
#     247         if self.training:
# --> 248             self.loss += model.loss(batch, preds)[1]
#     250 # Postprocess
#     251 with dt[3]:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\tasks.py:347, in BaseModel.loss(self, batch, preds)
#     345 if preds is None:
#     346     preds = self.forward(batch["img"])
# --> 347 return self.criterion(preds, batch)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\utils\loss.py:1195, in E2ELoss.__call__(self, preds, batch)
#    1193 one2many, one2one = preds["one2many"], preds["one2one"]
#    1194 loss_one2many = self.one2many.loss(one2many, batch)
# -> 1195 loss_one2one = self.one2one.loss(one2one, batch)
#    1196 return loss_one2many[0] * self.o2m + loss_one2one[0] * self.o2o, loss_one2one[1]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\utils\loss.py:481, in v8DetectionLoss.loss(self, preds, batch)
#     479 """Calculate detection loss using assigned targets."""
#     480 batch_size = preds["boxes"].shape[0]
# --> 481 loss, loss_detach = self.get_assigned_targets_and_loss(preds, batch)[1:]
#     482 return loss * batch_size, loss_detach
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\utils\loss.py:424, in v8DetectionLoss.get_assigned_targets_and_loss(self, preds, batch)
#     421 # Pboxes
#     422 pred_bboxes = self.bbox_decode(anchor_points, pred_distri)  # xyxy, (b, h*w, 4)
# --> 424 _, target_bboxes, target_scores, fg_mask, target_gt_idx = self.assigner(
#     425     pred_scores.detach().sigmoid(),
#     426     (pred_bboxes.detach() * stride_tensor).type(gt_bboxes.dtype),
#     427     anchor_points * stride_tensor,
#     428     gt_labels,
#     429     gt_bboxes,
#     430     mask_gt,
#     431 )
#     433 target_scores_sum = max(target_scores.sum(), 1)
#     435 # Cls loss with optional class weighting
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\utils\tal.py:98, in TaskAlignedAssigner.forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      89     return (
#      90         torch.full_like(pd_scores[..., 0], self.num_classes),
#      91         torch.zeros_like(pd_bboxes),
#    (...)     94         torch.zeros_like(pd_scores[..., 0]),
#      95     )
#      97 try:
# ---> 98     return self._forward(pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      99 except RuntimeError as e:
#     100     if "out of memory" not in str(e).lower():
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\utils\tal.py:126, in TaskAlignedAssigner._forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#     108 def _forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt):
#     109     """Compute the task-aligned assignment.
#     110
#     111     Args:
#    (...)    124         target_gt_idx (torch.Tensor): Target ground truth indices with shape (bs, num_total_anchors).
#     125     """
# --> 126     mask_pos, align_metric, overlaps = self.get_pos_mask(
#     127         pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points, mask_gt
#     128     )
#     130     target_gt_idx, fg_mask, mask_pos = self.select_highest_overlaps(
#     131         mask_pos, overlaps, self.n_max_boxes, align_metric
#     132     )
#     134     # Assigned target
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\utils\tal.py:164, in TaskAlignedAssigner.get_pos_mask(self, pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points, mask_gt)
#     162 mask_in_gts = self.select_candidates_in_gts(anc_points, gt_bboxes, mask_gt)
#     163 # Get anchor_align metric, (b, max_num_obj, h*w)
# --> 164 align_metric, overlaps = self.get_box_metrics(pd_scores, pd_bboxes, gt_labels, gt_bboxes, mask_in_gts * mask_gt)
#     165 # Get topk_metric mask, (b, max_num_obj, h*w)
#     166 mask_topk = self.select_topk_candidates(align_metric, topk_mask=mask_gt.expand(-1, -1, self.topk).bool())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\utils\tal.py:200, in TaskAlignedAssigner.get_box_metrics(self, pd_scores, pd_bboxes, gt_labels, gt_bboxes, mask_gt)
#     198 pd_boxes = pd_bboxes.unsqueeze(1).expand(-1, self.n_max_boxes, -1, -1)[mask_gt]
#     199 gt_boxes = gt_bboxes.unsqueeze(2).expand(-1, -1, na, -1)[mask_gt]
# --> 200 overlaps[mask_gt] = self.iou_calculation(gt_boxes, pd_boxes)
#     202 align_metric = bbox_scores.pow(self.alpha) * overlaps.pow(self.beta)
#     203 return align_metric, overlaps
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\utils\tal.py:215, in TaskAlignedAssigner.iou_calculation(self, gt_bboxes, pd_bboxes)
#     205 def iou_calculation(self, gt_bboxes, pd_bboxes):
#     206     """Calculate IoU for horizontal bounding boxes.
#     207
#     208     Args:
#    (...)    213         (torch.Tensor): IoU values between each pair of boxes.
#     214     """
# --> 215     return bbox_iou(gt_bboxes, pd_bboxes, xywh=False, CIoU=True).squeeze(-1).clamp_(0)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\utils\metrics.py:164, in bbox_iou(box1, box2, xywh, GIoU, DIoU, CIoU, eps)
#     160 rho2 = (
#     161     (b2_x1 + b2_x2 - b1_x1 - b1_x2).pow(2) + (b2_y1 + b2_y2 - b1_y1 - b1_y2).pow(2)
#     162 ) / 4  # center dist**2
#     163 if CIoU:  # https://github.com/Zzh-tju/DIoU-SSD-pytorch/blob/master/utils/box/box_utils.py#L47
# --> 164     v = (4 / math.pi**2) * ((w2 / h2).atan() - (w1 / h1).atan()).pow(2)
#     165     with torch.no_grad():
#     166         alpha = v / (v - iou + (1 + eps))
#
# KeyboardInterrupt:
